# %%
import pandas as pd

# %%
tfl_df = pd.read_csv('tfl-daily-cycle-hires.csv')

# %%
tfl_df
# Out:
#              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]

# %%
tfl_df.info
# Out:
# <bound method DataFrame.info of              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]>

# %%
tfl_df.columns
# Out:
# Index(['Day', 'Number of Bicycle Hires', 'Unnamed: 2'], dtype='object')

# %%
tfl_df.describe
# Out:
# <bound method NDFrame.describe of              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]>

# %%
tfl_df.info
# Out:
# <bound method DataFrame.info of              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]>

# %%
tfl_df.dtypes
# Out:
# Day                         object
# Number of Bicycle Hires    float64
# Unnamed: 2                 float64
# dtype: object

# %%
tfl_df.sample
# Out:
# <bound method NDFrame.sample of              Day  Number of Bicycle Hires  Unnamed: 2
# 0     30/07/2010                   6897.0         NaN
# 1     31/07/2010                   5564.0         NaN
# 2     01/08/2010                   4303.0         NaN
# 3     02/08/2010                   6642.0         NaN
# 4     03/08/2010                   7966.0         NaN
# ...          ...                      ...         ...
# 4076  26/09/2021                  45120.0         NaN
# 4077  27/09/2021                  32167.0         NaN
# 4078  28/09/2021                  32539.0         NaN
# 4079  29/09/2021                  39889.0         NaN
# 4080  30/09/2021                  34070.0         NaN
#
# [4081 rows x 3 columns]>

# %%
tfl_df.shape
# Out:
# (4081, 3)

# %%
tfl_df.drop(columns='Unnamed: 2', inplace = True)

# %%
tfl_df
# Out:
#              Day  Number of Bicycle Hires
# 0     30/07/2010                   6897.0
# 1     31/07/2010                   5564.0
# 2     01/08/2010                   4303.0
# 3     02/08/2010                   6642.0
# 4     03/08/2010                   7966.0
# ...          ...                      ...
# 4076  26/09/2021                  45120.0
# 4077  27/09/2021                  32167.0
# 4078  28/09/2021                  32539.0
# 4079  29/09/2021                  39889.0
# 4080  30/09/2021                  34070.0
#
# [4081 rows x 2 columns]

# %%
tfl_df.dtypes
# Out:
# Day                         object
# Number of Bicycle Hires    float64
# dtype: object

# %%
#tfl_df['Day']=pd.to_datetime(tfl_df['Day'],format="%d-%m-%Y")

# %%
tfl_df
# Out:
#              Day  Number of Bicycle Hires
# 0     30/07/2010                   6897.0
# 1     31/07/2010                   5564.0
# 2     01/08/2010                   4303.0
# 3     02/08/2010                   6642.0
# 4     03/08/2010                   7966.0
# ...          ...                      ...
# 4076  26/09/2021                  45120.0
# 4077  27/09/2021                  32167.0
# 4078  28/09/2021                  32539.0
# 4079  29/09/2021                  39889.0
# 4080  30/09/2021                  34070.0
#
# [4081 rows x 2 columns]

# %%
#tfl_df['Month']=pd.to_datetime(tfl_df['Day'],format="%b")
tfl_df["Day"] = pd.to_datetime(tfl_df["Day"], dayfirst=True, errors="coerce")

# %%
tfl_df
# Out:
#             Day  Number of Bicycle Hires
# 0    2010-07-30                   6897.0
# 1    2010-07-31                   5564.0
# 2    2010-08-01                   4303.0
# 3    2010-08-02                   6642.0
# 4    2010-08-03                   7966.0
# ...         ...                      ...
# 4076 2021-09-26                  45120.0
# 4077 2021-09-27                  32167.0
# 4078 2021-09-28                  32539.0
# 4079 2021-09-29                  39889.0
# 4080 2021-09-30                  34070.0
#
# [4081 rows x 2 columns]

# %%
tfl_df['Month']=tfl_df['Day'].dt.strftime('%b')

# %%
tfl_df
# Out:
#             Day  Number of Bicycle Hires Month
# 0    2010-07-30                   6897.0   Jul
# 1    2010-07-31                   5564.0   Jul
# 2    2010-08-01                   4303.0   Aug
# 3    2010-08-02                   6642.0   Aug
# 4    2010-08-03                   7966.0   Aug
# ...         ...                      ...   ...
# 4076 2021-09-26                  45120.0   Sep
# 4077 2021-09-27                  32167.0   Sep
# 4078 2021-09-28                  32539.0   Sep
# 4079 2021-09-29                  39889.0   Sep
# 4080 2021-09-30                  34070.0   Sep
#
# [4081 rows x 3 columns]

# %%
tfl_df['Year']=tfl_df['Day'].dt.year

# %%
tfl_df
# Out:
#             Day  Number of Bicycle Hires Month  Year
# 0    2010-07-30                   6897.0   Jul  2010
# 1    2010-07-31                   5564.0   Jul  2010
# 2    2010-08-01                   4303.0   Aug  2010
# 3    2010-08-02                   6642.0   Aug  2010
# 4    2010-08-03                   7966.0   Aug  2010
# ...         ...                      ...   ...   ...
# 4076 2021-09-26                  45120.0   Sep  2021
# 4077 2021-09-27                  32167.0   Sep  2021
# 4078 2021-09-28                  32539.0   Sep  2021
# 4079 2021-09-29                  39889.0   Sep  2021
# 4080 2021-09-30                  34070.0   Sep  2021
#
# [4081 rows x 4 columns]

# %%
tfl_df.dtypes
# Out:
# Day                        datetime64[ns]
# Number of Bicycle Hires           float64
# Month                              object
# Year                                int32
# dtype: object

# %%
tfl_df['YYYY-MMM']=tfl_df['Year']+'-'+tfl_df['Month']
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 tfl_df['YYYY-MMM']=tfl_df['Year']+'-'+tfl_df['Month']
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)    184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# ...
